# %%
import pandas as pd
import numpy as np
import os

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# /home/anamaria/code/nusero92/aviation

# %%
url="/home/anamaria/code/nusero92/aviation/avia_paoc__custom_9158605_spreadsheet.xlsx"

# %%
data=pd.read_excel(url, sheet_name='Sheet 1')

# %%
data
# Out:
#    Data extracted on 30/12/2023 16:07:03 from [ESTAT]  \
# 0                                           Dataset:
# 1                                      Last updated:
# 2                                                 NaN
# 3                                      Time frequency
# 4                                     Unit of measure
# 5                   Traffic and transport measurement
# 6                                  Transport coverage
# 7                                    Type of schedule
# 8                                                 NaN
# 9                                                TIME
# 10                                       GEO (Labels)
# 11          European Union - 28 countries (2013-2020)
# 12                                            Belgium
# 13                                           Bulgaria
# 14                                            Czechia
# 15                                            Denmark
# ...
